# %%
import pandas as pd

# Load CSV file
df = pd.read_csv("/content/sample_data/california_housing_train.csv") # Changed 'data.csv' to an existing sample file

# Display basic info
print("First 5 rows:")
print(df.head())

print("\nDataset Info:")
print(df.info())
# Out:
# First 5 rows:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/sample_data/california_housing_train.csv")

# Remove duplicate rows
df = df.drop_duplicates()

# Handle missing values
df = df.dropna()

# Convert column names to lowercase
df.columns = df.columns.str.lower()

# Save cleaned data
df.to_csv("cleaned_data.csv", index=False)

print("Data cleaned successfully!")
# Out:
# Data cleaned successfully!

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("cleaned_data.csv")

# Convert a column to NumPy array (example: temperature)
data = np.array(df.select_dtypes(include=np.number))

print("Mean:", np.mean(data))
print("Median:", np.median(data))
print("Standard Deviation:", np.std(data))
# Out:
# Mean: 23595.9243909
# Median: 276.0
# Standard Deviation: 75594.08266134262

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("cleaned_data.csv")

# Plot first numerical column
column = df.select_dtypes(include='number').columns[0]

plt.figure()
plt.plot(df[column])
plt.xlabel("Index")
plt.ylabel(column)
plt.title(f"{column} Trend")
plt.show()
